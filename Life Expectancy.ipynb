# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
# %matplotlib inline

# %% [markdown]
#  The LifeExpectancy.csv was retrieved from a data201 course webpage. First thing to do is read it into Python, skip the necessary rows and read the header. Make the country name be an index. We should probably print the first few rows to ensure that you have it correct.

# %%
# skipping the necessary rows and reading the header
life = pd.read_csv("C:/Users/dangu/OneDrive/Desktop/data201/LifeExpectancy.csv", skiprows=3, parse_dates=True)
# Make the country name be an index
l =life.set_index('Country Name', inplace=True)
display('Life Expectancy')
#  Print the first few rows
life.head()
# Out:
# 'Life Expectancy'
#              Country Code                           Indicator Name  \
# Country Name
# Aruba                 ABW  Life expectancy at birth, total (years)
# Afghanistan           AFG  Life expectancy at birth, total (years)
# Angola                AGO  Life expectancy at birth, total (years)
# Albania               ALB  Life expectancy at birth, total (years)
# Andorra               AND  Life expectancy at birth, total (years)
#
#               Indicator Code    1960    1961    1962    1963    1964    1965  \
# Country Name
# Aruba         SP.DYN.LE00.IN  65.662  66.074  66.444  66.787  67.113  67.435
# Afghanistan   SP.DYN.LE00.IN  32.446  32.962  33.471  33.971  34.463  34.948
# Angola        SP.DYN.LE00.IN  37.524  37.811  38.113  38.430  38.760  39.102
# Albania       SP.DYN.LE00.IN  62.283  63.301  64.190  64.914  65.463  65.850
# Andorra       SP.DYN.LE00.IN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                 1966  ...    2010    2011    2012    2013    2014    2015  \
# Country Name          ...
# Aruba         67.762  ...  75.017  75.158  75.299  75.441  75.583  75.725
# Afghanistan   35.430  ...  61.028  61.553  62.054  62.525  62.966  63.377
# Angola        39.454  ...  55.350  56.330  57.236  58.054  58.776  59.398
# Albania       66.110  ...  76.562  76.914  77.252  77.554  77.813  78.025
# Andorra          NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
#                 2016    2017  2018  2019
# Country Name
# Aruba         75.868  76.010   NaN   NaN
# Afghanistan   63.763  64.130   NaN   NaN
# Angola        59.925  60.379   NaN   NaN
# Albania       78.194  78.333   NaN   NaN
# Andorra          NaN     NaN   NaN   NaN
#
# [5 rows x 63 columns]

# %% [markdown]
# Drop rows that consist of NaN values. Be careful how you do this, the naive way of just using dropna() without looking at the data a bit might not do what you expect.
# You might need to know that to delete a column you can use `life.drop([list of column names],axis=1`.

# %%
#drops all the columns
l = life.drop(['2018', '2019'],axis=1)
l = l.dropna(how = 'any')
l
# Out:
#              Country Code                           Indicator Name  \
# Country Name
# Aruba                 ABW  Life expectancy at birth, total (years)
# Afghanistan           AFG  Life expectancy at birth, total (years)
# Angola                AGO  Life expectancy at birth, total (years)
# Albania               ALB  Life expectancy at birth, total (years)
# Arab World            ARB  Life expectancy at birth, total (years)
# ...                   ...                                      ...
# Samoa                 WSM  Life expectancy at birth, total (years)
# Yemen, Rep.           YEM  Life expectancy at birth, total (years)
# South Africa          ZAF  Life expectancy at birth, total (years)
# Zambia                ZMB  Life expectancy at birth, total (years)
# Zimbabwe              ZWE  Life expectancy at birth, total (years)
#
#               Indicator Code       1960       1961       1962       1963  \
# Country Name
# Aruba         SP.DYN.LE00.IN  65.662000  66.074000  66.444000  66.787000
# Afghanistan   SP.DYN.LE00.IN  32.446000  32.962000  33.471000  33.971000
# Angola        SP.DYN.LE00.IN  37.524000  37.811000  38.113000  38.430000
# Albania       SP.DYN.LE00.IN  62.283000  63.301000  64.190000  64.914000
# Arab World    SP.DYN.LE00.IN  46.546909  47.141621  47.731783  48.320432
# ...                      ...        ...        ...        ...        ...
# Samoa         SP.DYN.LE00.IN  56.902000  57.188000  57.472000  57.756000
# Yemen, Rep.   SP.DYN.LE00.IN  29.919000  30.163000  30.500000  30.943000
# South Africa  SP.DYN.LE00.IN  48.406000  48.777000  49.142000  49.509000
# Zambia        SP.DYN.LE00.IN  46.687000  47.084000  47.446000  47.772000
# Zimbabwe      SP.DYN.LE00.IN  53.019000  53.483000  53.946000  54.403000
#
#                    1964       1965       1966  ...       2008      2009  \
# Country Name                                   ...
# Aruba         67.113000  67.435000  67.762000  ...  74.725000  74.87200
# Afghanistan   34.463000  34.948000  35.430000  ...  59.930000  60.48400
# Angola        38.760000  39.102000  39.454000  ...  53.243000  54.31100
# Albania       65.463000  65.850000  66.110000  ...  75.912000  76.22100
# Arab World    48.910019  49.496478  50.072947  ...  69.942174  70.15756
# ...                 ...        ...        ...  ...        ...       ...
# Samoa         58.045000  58.340000  58.642000  ...  71.158000  71.41200
# Yemen, Rep.   31.501000  32.175000  32.960000  ...  64.892000  65.25500
# South Africa  49.888000  50.284000  50.705000  ...  55.360000  56.46000
# Zambia        48.068000  48.351000  48.643000  ...  52.606000  54.13000
# Zimbabwe      54.849000  55.274000  55.671000  ...  46.504000  48.44900
#
#                    2010       2011       2012       2013       2014  \
# Country Name
# Aruba         75.017000  75.158000  75.299000  75.441000  75.583000
# Afghanistan   61.028000  61.553000  62.054000  62.525000  62.966000
# Angola        55.350000  56.330000  57.236000  58.054000  58.776000
# Albania       76.562000  76.914000  77.252000  77.554000  77.813000
# Arab World    70.349916  70.528775  70.703827  70.882254  71.064292
# ...                 ...        ...        ...        ...        ...
# Samoa         71.663000  71.906000  72.136000  72.351000  72.549000
# Yemen, Rep.   65.549000  65.768000  65.920000  66.016000  66.066000
# South Africa  57.669000  58.895000  60.060000  61.099000  61.968000
# Zambia        55.655000  57.126000  58.502000  59.746000  60.831000
# Zimbabwe      50.640000  52.896000  55.032000  56.897000  58.410000
#
#                    2015       2016       2017
# Country Name
# Aruba         75.725000  75.868000  76.010000
# Afghanistan   63.377000  63.763000  64.130000
# Angola        59.398000  59.925000  60.379000
# Albania       78.025000  78.194000  78.333000
# Arab World    71.249571  71.436497  71.622526
# ...                 ...        ...        ...
# Samoa         72.730000  72.895000  73.046000
# Yemen, Rep.   66.085000  66.087000  66.086000
# South Africa  62.649000  63.153000  63.538000
# Zambia        61.737000  62.464000  63.043000
# Zimbabwe      59.534000  60.294000  60.812000
#
# [235 rows x 61 columns]

# %% [markdown]
# Now plot the curves of life expectancy against time on 1 plot for the following countries:
# Afghanistan, Nepal, New Zealand, Netherlands
# Include a legend, and make the labels on the $x$-axis readable.

# %%
#life expectancy vs time: Afghanistan, Nepal, New Zealand, Netherlands, legend, and make the labels on the  𝑥 -axis readable
afghan = life.iloc[1,5:-1]
afghan.plot(label = 'Afghanistan')

nepal = life.iloc[176,5:-1]
pl.plot(nepal, 'g', label = 'Nepal')

nz = life.iloc[178,5:-1]
pl.plot(nz, 'b', label = 'NZ')

nether = life.iloc[174,5:-1]
pl.plot(nether, color='yellow', label = 'Netherlands')

pl.xlabel('Time')
pl.ylabel('Life Expectancy(years)')

pl.legend()
pl.title('Life expectancy of Afghanistan, Nepal, New Zealand, Netherlands Line Graph(1960-2017)')
# Out:
# Text(0.5, 1.0, 'Life expectancy of Afghanistan, Nepal, New Zealand, Netherlands Line Graph(1960-2017)')

# %% [markdown]
# Plot Rwanda separately, and explain briefly why it has that shape (hint: use wikipedia)

# %%
rwanda = life.iloc[201,5:-1]
rwanda.plot( color='yellow')
pl.xlabel('Time')
pl.ylabel('Life Expectancy(years)')

pl.legend()
pl.title('Life expectancy of Rwanda Line Graph(1960-2017)')
#The cause is a genocide that occured around that time in rwanda around 1994. 
#It explains the huge dip as millions of people died during that period
# Out:
# Text(0.5, 1.0, 'Life expectancy of Rwanda Line Graph(1960-2017)')

# %% [markdown]
# Can you detect any other countries where the life expectancy drops significantly?
#
# To compute this write some loops over each country and each year. If the next value is below 95% of the current value, print the name of the country.

# %%
#life = l.reset_index(drop=True)

# %%
#inner loop is always completed first
#r starts as 0, then does all columns does all of c 0-finish
# drop the irrelevant countries
l = l.drop(['Country Code', 'Indicator Name', 'Indicator Code'], axis=1)
l
# Out:
#                    1960       1961       1962       1963       1964  \
# Country Name
# Aruba         65.662000  66.074000  66.444000  66.787000  67.113000
# Afghanistan   32.446000  32.962000  33.471000  33.971000  34.463000
# Angola        37.524000  37.811000  38.113000  38.430000  38.760000
# Albania       62.283000  63.301000  64.190000  64.914000  65.463000
# Arab World    46.546909  47.141621  47.731783  48.320432  48.910019
# ...                 ...        ...        ...        ...        ...
# Samoa         56.902000  57.188000  57.472000  57.756000  58.045000
# Yemen, Rep.   29.919000  30.163000  30.500000  30.943000  31.501000
# South Africa  48.406000  48.777000  49.142000  49.509000  49.888000
# Zambia        46.687000  47.084000  47.446000  47.772000  48.068000
# Zimbabwe      53.019000  53.483000  53.946000  54.403000  54.849000
#
#                    1965       1966       1967     1968       1969  ...  \
# Country Name                                                       ...
# Aruba         67.435000  67.762000  68.095000  68.4360  68.784000  ...
# Afghanistan   34.948000  35.430000  35.914000  36.4030  36.900000  ...
# Angola        39.102000  39.454000  39.813000  40.1780  40.546000  ...
# Albania       65.850000  66.110000  66.304000  66.4870  66.689000  ...
# Arab World    49.496478  50.072947  50.634415  51.1821  51.722024  ...
# ...                 ...        ...        ...      ...        ...  ...
# Samoa         58.340000  58.642000  58.951000  59.2660  59.589000  ...
# Yemen, Rep.   32.175000  32.960000  33.836000  34.7800  35.780000  ...
# South Africa  50.284000  50.705000  51.148000  51.6150  52.106000  ...
# Zambia        48.351000  48.643000  48.960000  49.3130  49.700000  ...
# Zimbabwe      55.274000  55.671000  56.034000  56.3620  56.656000  ...
#
#                    2008      2009       2010       2011       2012       2013  \
# Country Name
# Aruba         74.725000  74.87200  75.017000  75.158000  75.299000  75.441000
# Afghanistan   59.930000  60.48400  61.028000  61.553000  62.054000  62.525000
# Angola        53.243000  54.31100  55.350000  56.330000  57.236000  58.054000
# Albania       75.912000  76.22100  76.562000  76.914000  77.252000  77.554000
# Arab World    69.942174  70.15756  70.349916  70.528775  70.703827  70.882254
# ...                 ...       ...        ...        ...        ...        ...
# Samoa         71.158000  71.41200  71.663000  71.906000  72.136000  72.351000
# Yemen, Rep.   64.892000  65.25500  65.549000  65.768000  65.920000  66.016000
# South Africa  55.360000  56.46000  57.669000  58.895000  60.060000  61.099000
# Zambia        52.606000  54.13000  55.655000  57.126000  58.502000  59.746000
# Zimbabwe      46.504000  48.44900  50.640000  52.896000  55.032000  56.897000
#
#                    2014       2015       2016       2017
# Country Name
# Aruba         75.583000  75.725000  75.868000  76.010000
# Afghanistan   62.966000  63.377000  63.763000  64.130000
# Angola        58.776000  59.398000  59.925000  60.379000
# Albania       77.813000  78.025000  78.194000  78.333000
# Arab World    71.064292  71.249571  71.436497  71.622526
# ...                 ...        ...        ...        ...
# Samoa         72.549000  72.730000  72.895000  73.046000
# Yemen, Rep.   66.066000  66.085000  66.087000  66.086000
# South Africa  61.968000  62.649000  63.153000  63.538000
# Zambia        60.831000  61.737000  62.464000  63.043000
# Zimbabwe      58.410000  59.534000  60.294000  60.812000
#
# [235 rows x 58 columns]

# %%
#l.index.values is a reference point for the first loop, looping the rows as index values.
for r in l.index.values:
    #previous value has to be inside for loop.
    prevVal = 0
    for c in l:
        #inside loop works like [col][row] instead of [row][col]
        if prevVal-(prevVal/20) > l[c][r]:
            print(r)
            #break when if statement is found to avoid doubles.            
            break
            #else set the previous variable to be current one.
        else:
            prevVal = l[c][r]
# Out:
# Cambodia
# Rwanda

# %% [markdown]
# Compute the mean life expectancy for each of the countries over the whole 57 years.
# Plot a bar chart of this for the first 10 countries.

# %%
#get columns 3 to 61 to get 1960-2017
#first 10 rows
# the mean for each 10 countries
l.iloc[0:10,3:61].mean(axis=1)
# Out:
# Country Name
# Aruba                   72.613945
# Afghanistan             49.520582
# Angola                  46.729200
# Albania                 71.891109
# Arab World              62.368065
# United Arab Emirates    69.985818
# Argentina               71.251855
# Armenia                 70.755036
# Antigua and Barbuda     71.025982
# Australia               76.694173
# dtype: float64

# %%
#l is the new editted form
#l.columns
mean = l.iloc[0:10,3:61].mean(axis=1)
mean.plot.bar()
pl.xlabel('First 10 countries.')
pl.ylabel('Mean Life expectancy')
pl.title('Mean life expectancy for each of the countries over the whole 57 years ')
# Out:
# Text(0.5, 1.0, 'Mean life expectancy for each of the countries over the whole 57 years ')

# %% [markdown]
# Find the 5 countries with the highest mean life expectancy and the 5 with the lowest. You might find `life.sort_values()` helpful, as well as `pd.concat`and `life.transpose`. Plot a box and whisker plot of these countries.

# %%
l['mean'] = l.mean(numeric_only=True, axis = 1)
# l.sort_values() Sort by the values along either axis.
meanframe = l.sort_values(by='mean', ascending = False)


#Take the top 5
topfive = meanframe.head()
#Take the bottom 5
botfive = meanframe.tail()

#combine both new dataframes
combined = [topfive,botfive]
together = pd.concat(combined)
newframe = together.drop(['mean'], axis=1)

# life.transpose()Flips it diagonally.
# transpose the new dataframe
Nf = newframe.transpose()


#plot a box and whisker of all the countries.
boxplot = Nf.boxplot()
boxplot
